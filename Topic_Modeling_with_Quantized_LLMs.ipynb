# %% [markdown]
# <a href="https://colab.research.google.com/github/tumikosha/notebooks/blob/main/Topic_Modeling_with_Quantized_LLMs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Topic Modeling with Quantized LLMs**
# *Create easily interpretable topics with BERTopic and LLMs*
# <br>
#
# <img src="https://pbs.twimg.com/media/GDA2JQoX0AElWoq?format=jpg&name=large">

# %% [markdown]
# ---
#
# 💡 **NOTE**: We will want to use a GPU to run both 7B LLMs as well as BERTopic for this use case. In Google Colab, go to
# **Runtime > Change runtime type > Hardware accelerator > GPU > GPU type > T4**.
#
# ---

# %% [markdown]
# We will start by installing a number of packages that we are going to use throughout this example:

# %%
# @title Default title text
# %%capture
# BERTopic + llama-cpp-python
# !CMAKE_ARGS="-DLLAMA_CUBLAS=on" FORCE_CMAKE=1 pip install llama-cpp-python
# !pip install bertopic datasets

# DataMapPlot
# !git clone https://github.com/TutteInstitute/datamapplot.git
# !pip install datamapplot/.

# GPU-accelerated HDBSCAN + UMAP
# !pip install cudf-cu12 dask-cudf-cu12 --extra-index-url=https://pypi.nvidia.com
# !pip install cuml-cu12 --extra-index-url=https://pypi.nvidia.com
# !pip install cugraph-cu12 --extra-index-url=https://pypi.nvidia.com
# !pip install cupy-cuda12x -f https://pip.cupy.dev/aarch64

# %% [markdown]
# # 📄 **Data**
#
# We are going to apply topic modeling on a number of ArXiv abstracts. They are a great source for topic modeling since they contain a wide variety of topics and are generally well-written.

# %%
from datasets import load_dataset

# ArXiv ML Documents
docs = load_dataset("CShorten/ML-ArXiv-Papers")["train"]["abstract"]
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:72: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Downloading readme:   0%|          | 0.00/986 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:72: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Downloading data:   0%|          | 0.00/147M [00:00<?, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]

# %% [markdown]
# # 🦙 **Quantized LLM**

# %% [markdown]
# To use a quantized LLMs, we make use of the `GGUF` format together with `llama-cpp-python`. When you access any of [TheBloke's quantized models](https://huggingface.co/TheBloke), you can click on files and find specific quantized formats. We are going with a 4-bit quantized model:

# %%
# !wget https://huggingface.co/TheBloke/OpenHermes-2.5-Mistral-7B-GGUF/resolve/main/openhermes-2.5-mistral-7b.Q4_K_M.gguf
# !wget https://huggingface.co/TheBloke/dolphin-2.7-mixtral-8x7b-GGUF/resolve/main/dolphin-2.7-mixtral-8x7b.Q3_K_M.gguf
# Out:
# --2024-01-04 15:44:14--  https://huggingface.co/TheBloke/OpenHermes-2.5-Mistral-7B-GGUF/resolve/main/openhermes-2.5-mistral-7b.Q4_K_M.gguf
# Resolving huggingface.co (huggingface.co)... 18.172.134.4, 18.172.134.88, 18.172.134.24, ...
# Connecting to huggingface.co (huggingface.co)|18.172.134.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cdn-lfs-us-1.huggingface.co/repos/65/3b/653b1cc7a4558cd22c0ac02df471105878a080cb5694622ccd566697c574592f/cd58120326971c71c0590f6b7084a0744e287ce9c67275d8b4bf34a5947d950b?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27openhermes-2.5-mistral-7b.Q4_K_M.gguf%3B+filename%3D%22openhermes-2.5-mistral-7b.Q4_K_M.gguf%22%3B&Expires=1704642254&Policy=&Signature=mmsNGcI%7EMPtNVp6b2sf1BvJ-ez4y5WeUfQs5BkteYqOxOzorrDLVaKxM4J3H1BiOQQW0c3enw8PLXO6SfpkfyuqAjK23IwIRk%7Efg0pXd%7EFxluyEYi2ZDTZXk-WCPz5LDO0sOM3CeA5L1vXpHB5BC29njcCj7bEHjRmGFXKNIGB1UUZMo0PtlmY0d31x6DkYSx6JgzQU9XAcJC9Vn65jQg0llUru2m8q7yaKJVFu4xt%7E4atBLiN6TKjbp8yQMtu3wlQc98cofJ2n%7E6oy27tVCOo7uOINXjL-xttBuwss8DDrbj6IlPkvzp-ayZLdmOhKGzYPVrFHv%7EiYtW4BlJwXiAw__&Key-Pair-Id=KCD77M1F0VK2B [following]
# --2024-01-04 15:44:14--  https://cdn-lfs-us-1.huggingface.co/repos/65/3b/653b1cc7a4558cd22c0ac02df471105878a080cb5694622ccd566697c574592f/cd58120326971c71c0590f6b7084a0744e287ce9c67275d8b4bf34a5947d950b?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27openhermes-2.5-mistral-7b.Q4_K_M.gguf%3B+filename%3D%22openhermes-2.5-mistral-7b.Q4_K_M.gguf%22%3B&Expires=1704642254&Policy=&Signature=mmsNGcI%7EMPtNVp6b2sf1BvJ-ez4y5WeUfQs5BkteYqOxOzorrDLVaKxM4J3H1BiOQQW0c3enw8PLXO6SfpkfyuqAjK23IwIRk%7Efg0pXd%7EFxluyEYi2ZDTZXk-WCPz5LDO0sOM3CeA5L1vXpHB5BC29njcCj7bEHjRmGFXKNIGB1UUZMo0PtlmY0d31x6DkYSx6JgzQU9XAcJC9Vn65jQg0llUru2m8q7yaKJVFu4xt%7E4atBLiN6TKjbp8yQMtu3wlQc98cofJ2n%7E6oy27tVCOo7uOINXjL-xttBuwss8DDrbj6IlPkvzp-ayZLdmOhKGzYPVrFHv%7EiYtW4BlJwXiAw__&Key-Pair-Id=KCD77M1F0VK2B
# Resolving cdn-lfs-us-1.huggingface.co (cdn-lfs-us-1.huggingface.co)... 108.156.107.49, 108.156.107.29, 108.156.107.44, ...
# Connecting to cdn-lfs-us-1.huggingface.co (cdn-lfs-us-1.huggingface.co)|108.156.107.49|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4368450304 (4.1G) [binary/octet-stream]
# Saving to: ‘openhermes-2.5-mistral-7b.Q4_K_M.gguf’
#
# openhermes-2.5-mist 100%[===================>]   4.07G   159MB/s    in 36s
#
# 2024-01-04 15:44:51 (115 MB/s) - ‘openhermes-2.5-mistral-7b.Q4_K_M.gguf’ saved [4368450304/4368450304]

# %% [markdown]
# Next, we load the model using `llama-cpp-python`:

# %%
from llama_cpp import Llama

# Use llama.cpp to load in a Quantized LLM
llm = Llama(model_path="openhermes-2.5-mistral-7b.Q4_K_M.gguf", n_gpu_layers=-1, n_ctx=4096, stop=["Q:", "\n"])
# Out:
# AVX = 1 | AVX2 = 1 | AVX512 = 0 | AVX512_VBMI = 0 | AVX512_VNNI = 0 | FMA = 1 | NEON = 0 | ARM_FMA = 0 | F16C = 1 | FP16_VA = 0 | WASM_SIMD = 0 | BLAS = 1 | SSE3 = 1 | SSSE3 = 1 | VSX = 0 |

# %% [markdown]
# We pass the LLM to BERTopic with a custom prompt. Let's add `KeyBERTInspired` representations to compare the LLM representations with:

# %%
from bertopic.representation import KeyBERTInspired, LlamaCPP

prompt = """ Q:
I have a topic that contains the following documents:
[DOCUMENTS]

The topic is described by the following keywords: '[KEYWORDS]'.

Based on the above information, can you give a short label of the topic of at most 5 words?
A:
"""

representation_model = {
    "KeyBERT": KeyBERTInspired(),
    "LLM": LlamaCPP(llm, prompt=prompt),
}

# %% [markdown]
# # 🗨️ **BERTopic**

# %% [markdown]
# By pre-calculating the embeddings for each document, we can speed-up additional exploration steps and use the embeddings to quickly iterate over BERTopic's hyperparameters if needed.
#
# 🔥 **TIP**: You can find a great overview of good embeddings for clustering on the [MTEB Leaderboard](https://huggingface.co/spaces/mteb/leaderboard).

# %%
from sentence_transformers import SentenceTransformer
from cuml.manifold import UMAP
from cuml.cluster import HDBSCAN
# from umap import UMAP
# from hdbscan import HDBSCAN

# Pre-calculate embeddings
embedding_model = SentenceTransformer("BAAI/bge-small-en")
embeddings = embedding_model.encode(docs, show_progress_bar=True)

# Pre-reduce embeddings for visualization purposes
reduced_embeddings = UMAP(n_neighbors=15, n_components=2, min_dist=0.0, metric='cosine', random_state=42).fit_transform(embeddings)
# Out:
# .gitattributes:   0%|          | 0.00/1.52k [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/90.8k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/684 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/133M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/134M [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/366 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# Batches:   0%|          | 0/3675 [00:00<?, ?it/s]

# %%
# Define sub-models
umap_model = UMAP(n_neighbors=15, n_components=5, min_dist=0.0, metric='cosine', random_state=42)
hdbscan_model = HDBSCAN(min_cluster_size=400, metric='euclidean', cluster_selection_method='eom', prediction_data=True)

# %% [markdown]
# # 🔥 **Training**
#
# Now that we have our models prepared, we can start training our topic model! We supply BERTopic with the sub-models of interest, run `.fit_transform`, and see what kind of topics we get.

# %%
from bertopic import BERTopic

topic_model = BERTopic(

  # Sub-models
  embedding_model=embedding_model,
  umap_model=umap_model,
  hdbscan_model=hdbscan_model,
  representation_model=representation_model,

  # Hyperparameters
  top_n_words=10,
  verbose=True
)

# Train model
topics, probs = topic_model.fit_transform(docs, embeddings)
# Out:
# 2024-01-04 16:08:07,401 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2024-01-04 16:08:10,381 - BERTopic - Dimensionality - Completed ✓
# 2024-01-04 16:08:10,390 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2024-01-04 16:08:21,740 - BERTopic - Cluster - Completed ✓
# 2024-01-04 16:08:21,786 - BERTopic - Representation - Extracting topics from clusters using representation models.
#   3%|▎         | 1/36 [00:15<09:05, 15.57s/it]Llama.generate: prefix-match hit
#   6%|▌         | 2/36 [00:29<08:07, 14.33s/it]Llama.generate: prefix-match hit
#   8%|▊         | 3/36 [00:46<08:36, 15.66s/it]Llama.generate: prefix-match hit
#  11%|█         | 4/36 [01:01<08:17, 15.54s/it]Llama.generate: prefix-match hit
#  14%|█▍        | 5/36 [01:14<07:35, 14.68s/it]Llama.generate: prefix-match hit
#  17%|█▋        | 6/36 [01:33<08:05, 16.19s/it]Llama.generate: prefix-match hit
#  19%|█▉        | 7/36 [01:46<07:11, 14.87s/it]Llama.generate: prefix-match hit
#  22%|██▏       | 8/36 [01:57<06:26, 13.79s/it]Llama.generate: prefix-match hit
#  25%|██▌       | 9/36 [02:08<05:50, 12.97s/it]Llama.generate: prefix-match hit
#  28%|██▊       | 10/36 [02:21<05:32, 12.78s/it]Llama.generate: prefix-match hit
#  31%|███       | 11/36 [02:32<05:11, 12.46s/it]Llama.generate: prefix-match hit
#  33%|███▎      | 12/36 [02:45<05:02, 12.61s/it]Llama.generate: prefix-match hit
#  36%|███▌      | 13/36 [03:01<05:14, 13.69s/it]Llama.generate: prefix-match hit
#  39%|███▉      | 14/36 [03:16<05:09, 14.06s/it]Llama.generate: prefix-match hit
#  42%|████▏     | 15/36 [03:31<05:01, 14.35s/it]Llama.generate: prefix-match hit
#  44%|████▍     | 16/36 [03:46<04:49, 14.50s/it]Llama.generate: prefix-match hit
#  47%|████▋     | 17/36 [04:01<04:37, 14.59s/it]Llama.generate: prefix-match hit
#  50%|█████     | 18/36 [04:13<04:10, 13.92s/it]Llama.generate: prefix-match hit
#  53%|█████▎    | 19/36 [04:35<04:34, 16.14s/it]Llama.generate: prefix-match hit
#  56%|█████▌    | 20/36 [04:49<04:10, 15.64s/it]Llama.generate: prefix-match hit
#  58%|█████▊    | 21/36 [05:00<03:34, 14.28s/it]Llama.generate: prefix-match hit
#  61%|██████    | 22/36 [05:14<03:17, 14.09s/it]Llama.generate: prefix-match hit
#  64%|██████▍   | 23/36 [05:26<02:55, 13.46s/it]Llama.generate: prefix-match hit
#  67%|██████▋   | 24/36 [05:37<02:32, 12.68s/it]Llama.generate: prefix-match hit
#  69%|██████▉   | 25/36 [05:50<02:21, 12.91s/it]Llama.generate: prefix-match hit
#  72%|███████▏  | 26/36 [06:12<02:36, 15.70s/it]Llama.generate: prefix-match hit
#  75%|███████▌  | 27/36 [06:26<02:16, 15.20s/it]Llama.generate: prefix-match hit
#  78%|███████▊  | 28/36 [06:40<01:58, 14.85s/it]Llama.generate: prefix-match hit
#  81%|████████  | 29/36 [06:54<01:40, 14.33s/it]Llama.generate: prefix-match hit
#  83%|████████▎ | 30/36 [07:06<01:22, 13.76s/it]Llama.generate: prefix-match hit
#  86%|████████▌ | 31/36 [07:20<01:09, 13.95s/it]Llama.generate: prefix-match hit
#  89%|████████▉ | 32/36 [07:32<00:53, 13.28s/it]Llama.generate: prefix-match hit
#  92%|█████████▏| 33/36 [07:46<00:39, 13.32s/it]Llama.generate: prefix-match hit
#  94%|█████████▍| 34/36 [07:59<00:26, 13.38s/it]Llama.generate: prefix-match hit
#  97%|█████████▋| 35/36 [08:18<00:14, 14.92s/it]Llama.generate: prefix-match hit
# 100%|██████████| 36/36 [08:29<00:00, 14.17s/it]
# 2024-01-04 16:17:41,754 - BERTopic - Representation - Completed ✓

# %% [markdown]
# Now that we are done training our model, let's see what topics were generated:

# %%
# Show topics
topic_model.get_topic_info()
# Out:
#     Topic  Count                                           Name  \
# 0      -1  62289                               -1_the_of_and_to
# 1       0   8304            0_policy_the_learning_reinforcement
# 2       1   6184                                1_and_the_of_to
# 3       2   5621                          2_language_the_and_of
# 4       3   2764                     3_speech_audio_speaker_the
# 5       4   2728                    4_privacy_federated_fl_data
# 6       5   2101        5_adversarial_attacks_attack_robustness
# 7       6   1783                       6_graph_node_graphs_gnns
# 8       7   1744                  7_regret_bandit_the_algorithm
# 9       8   1684                       8_networks_neural_the_of
# 10      9   1623                           9_matrix_the_rank_of
# 11     10   1547                     10_traffic_driving_the_and
# 12     11   1528                   11_molecular_protein_drug_of
# 13     12   1396                        12_the_of_equations_and
# 14     13   1355        13_recommendation_user_item_recommender
# 15     14   1322                     14_channel_the_wireless_to
# 16     15   1189      15_gradient_stochastic_convergence_convex
# 17     16   1027                           16_3d_object_and_the
# 18     17    874                    17_hardware_and_pruning_the
# 19     18    806                        18_power_energy_the_and
# 20     19    797             19_gan_gans_generative_adversarial
# 21     20    751                    20_quantum_classical_the_of
# 22     21    728          21_inference_variational_gaussian_the
# 23     22    709            22_the_classification_of_classifier
# 24     23    703                 23_series_time_forecasting_the
# 25     24    632                            24_covid_19_the_and
# 26     25    624                         25_fairness_fair_in_of
# 27     26    596           26_clustering_means_clusters_cluster
# 28     27    591                     27_causal_variables_the_of
# 29     28    590             28_domain_adaptation_target_source
# 30     29    575                  29_stock_financial_market_the
# 31     30    550              30_explanations_explanation_to_of
# 32     31    508           31_vae_latent_generative_variational
# 33     32    480  32_continual_forgetting_learning_catastrophic
# 34     33    467            33_anomaly_detection_anomalies_data
# 35     34    422               34_malware_detection_traffic_the
#
#                                        Representation  \
# 0       [the, of, and, to, in, we, is, for, that, on]
# 1   [policy, the, learning, reinforcement, to, in,...
# 2   [and, the, of, to, in, for, data, is, medical,...
# 3   [language, the, and, of, to, text, in, we, on,...
# 4   [speech, audio, speaker, the, to, and, of, in,...
# 5   [privacy, federated, fl, data, the, learning, ...
# 6   [adversarial, attacks, attack, robustness, exa...
# 7   [graph, node, graphs, gnns, nodes, the, of, an...
# 8   [regret, bandit, the, algorithm, we, of, bandi...
# 9   [networks, neural, the, of, network, we, deep,...
# 10  [matrix, the, rank, of, we, is, kernel, in, an...
# 11  [traffic, driving, the, and, to, of, in, road,...
# 12  [molecular, protein, drug, of, molecules, and,...
# 13  [the, of, equations, and, to, physics, neural,...
# 14  [recommendation, user, item, recommender, user...
# 15  [channel, the, wireless, to, and, of, in, netw...
# 16  [gradient, stochastic, convergence, convex, sg...
# 17  [3d, object, and, the, to, of, we, segmentatio...
# 18  [hardware, and, pruning, the, to, of, dnn, mem...
# 19  [power, energy, the, and, of, to, load, electr...
# 20  [gan, gans, generative, adversarial, generator...
# 21  [quantum, classical, the, of, to, in, we, lear...
# 22  [inference, variational, gaussian, the, poster...
# 23  [the, classification, of, classifier, classifi...
# 24  [series, time, forecasting, the, of, and, to, ...
# 25  [covid, 19, the, and, of, pandemic, to, in, ch...
# 26  [fairness, fair, in, of, to, the, that, and, w...
# 27  [clustering, means, clusters, cluster, the, of...
# 28  [causal, variables, the, of, data, we, and, in...
# 29  [domain, adaptation, target, source, domains, ...
# 30  [stock, financial, market, the, trading, of, p...
# 31  [explanations, explanation, to, of, the, model...
# 32  [vae, latent, generative, variational, the, va...
# 33  [continual, forgetting, learning, catastrophic...
# 34  [anomaly, detection, anomalies, data, the, of,...
# 35  [malware, detection, traffic, the, to, of, and...
#
#                                               KeyBERT  \
# 0   [models, model, datasets, networks, algorithms...
# 1   [reinforcement, learning, dynamics, exploratio...
# 2   [convolutional, mri, imaging, segmentation, mo...
# 3   [nlp, embeddings, embedding, semantic, languag...
# 4   [voice, speech, language, models, model, train...
# 5   [federated, distributed, datasets, algorithms,...
# 6   [adversarial, adversarially, dnns, dnn, attack...
# 7   [graphs, graph, networks, gnns, embeddings, no...
# 8   [bandits, stochastic, algorithms, optimization...
# 9   [dnns, regularization, neural, gradient, conve...
# 10  [matrices, matrix, sparsity, sparse, regulariz...
# 11  [traffic, networks, forecasting, prediction, t...
# 12  [molecular, molecules, molecule, compounds, co...
# 13  [modeling, dynamics, models, pdes, simulations...
# 14  [recommender, embeddings, embedding, recommend...
# 15  [networks, network, beamforming, wireless, mod...
# 16  [minimization, gradients, stochastic, optimiza...
# 17  [3d, models, monocular, model, representations...
# 18  [dnns, cnns, dnn, convolutional, convolution, ...
# 19  [forecasting, forecasts, renewable, prediction...
# 20  [gans, adversarial, gan, generative, models, m...
# 21  [quantum, qubits, qubit, hamiltonian, entangle...
# 22  [bayesian, variational, stochastic, approximat...
# 23  [classifiers, classifier, classification, pred...
# 24  [forecasting, forecasts, prediction, datasets,...
# 25  [cov, coronavirus, covid, cxr, epidemic, ai, s...
# 26  [fairness, biases, predictive, bias, unfairnes...
# 27  [clustering, clusterings, clusters, cluster, a...
# 28  [causality, confounders, causal, inference, ob...
# 29  [adversarial, unsupervised, domain, supervised...
# 30  [volatility, investors, predicting, forecastin...
# 31  [models, predictive, prediction, explainabilit...
# 32  [encoders, autoencoders, modeling, autoencoder...
# 33  [forgetting, learning, continual, representati...
# 34  [unsupervised, outlier, anomaly, anomalies, de...
# 35  [networks, malware, adversarial, detection, cl...
#
#                                                   LLM  \
# 0   [Machine Learning Applications, , , , , , , , , ]
# 1   [Reinforcement Learning Policies\n\n\nQ:\nAnsw...
# 2   [Medical Image-to-Image Translation, Uncertain...
# 3   [Natural Language Processing (NLP) Models, , ,...
# 4    [Speech Processing Techniques, , , , , , , , , ]
# 5   [Federated Learning Privacy Enhancement, , , ,...
# 6   [-   Adversarial Attacks and Defenses in Neura...
# 7   [Graph Neural Networks (GNNs) for Representati...
# 8   [Multi-Armed Bandit Algorithms and Regret Boun...
# 9   ["Deep Neural Networks Learning", , , , , , , ...
# 10  [Low-rank matrix estimation and completion., ,...
# 11  ["Traffic Prediction & Deep Learning Models", ...
# 12  [\nMolecular Drug Binding Prediction, , , , , ...
# 13  ['Physics-Informed Neural ODEs', , , , , , , ,...
# 14  [Recommender Systems' Techniques, , , , , , , ...
# 15  [\nWireless Channel Optimization with Deep Lea...
# 16  [Stochastic Convex Optimization\n\nQ: \nI, , ,...
# 17  [3D Object Reconstruction and Perception, , , ...
# 18  ["DNN Model Compression for Hardware Efficienc...
# 19  [- Smart grid forecasting\n- Energy demand pre...
# 20  [Generative Adversarial Networks, , , , , , , ...
# 21  [Quantum Machine Learning Applications, , , , ...
# 22  [Variational Bayesian Inference\n\n1. What is ...
# 23  [Classification Ensemble Methods, , , , , , , ...
# 24  [Time Series Forecasting Methods, , , , , , , ...
# 25  [\n'COVID-19 Detection with Chest X-ray', , , ...
# 26  [Algorithmic Fairness for Neural Networks, , ,...
# 27  ["Clustering Algorithms and Techniques", , , ,...
# 28  [- Causal Inference from Observational Data\n-...
# 29      [Domain Adaptation Methods, , , , , , , , , ]
# 30         [Stock Price Prediction, , , , , , , , , ]
# 31  [Interpretable ML Explanations, , , , , , , , , ]
# 32  [Latent Variable Models in VAEs, , , , , , , ,...
# 33  [Continual Learning and Catastrophic Forgettin...
# 34   [Anomaly Detection Techniques, , , , , , , , , ]
# 35   [Malware Detection Strategies, , , , , , , , , ]
#
#                                   Representative_Docs
# 0   [  Designing complex architectures has been an...
# 1   [  Reinforcement learning (RL) algorithms aim ...
# 2   [  Computer-aided diagnosis (CAD) based on his...
# 3   [  Humans can infer a great deal about the mea...
# 4   [  Speaker recognition is a well known and stu...
# 5   [  Federated learning is a technique that enab...
# 6   [Deep Neural Networks (DNNs) have recently ach...
# 7   [  In the modern age of social media and netwo...
# 8   [  We study a decentralized cooperative stocha...
# 9   [  Deep neural networks' remarkable ability to...
# 10  [  This paper considers the problem of estimat...
# 11  [  Short-term traffic flow prediction is one o...
# 12  [  Designing accurate deep learning models for...
# 13  [  We present a novel deep learning approach t...
# 14  [  Dynamic recommendation is essential for mod...
# 15  [  We consider an opportunistic spectrum acces...
# 16  [  Stochastic gradient descent (SGD) is the op...
# 17  [  3D object detection and dense depth estimat...
# 18  [  Deep neural networks (DNNs) have become the...
# 19  [  Demand forecasting in power sector has beco...
# 20  [  Remarkable progress has been achieved in sy...
# 21  [  The study of quantum generative models is w...
# 22  [  We present a scalable approach to performin...
# 23  [  Classification is a fundamental problem in ...
# 24  [  Time series clustering is the process of gr...
# 25  [  Computer-aided diagnosis has become a neces...
# 26  [  Understanding and removing bias from the de...
# 27  [  Kernel-based clustering algorithms have the...
# 28  [  This paper discusses the problem of causal ...
# 29  [  Early Unsupervised Domain Adaptation (UDA) ...
# 30  [  The prediction of stock price movement dire...
# 31  [  Locally interpretable model agnostic explan...
# 32  [  Variational autoencoders learn distribution...
# 33  [  We propose a new method for unsupervised ge...
# 34  [  Anomaly detection is typically posited as a...
# 35  [  In cyberattack detection and prevention sys...

# %% [markdown]
# # 📊 Visualization with DataMapPlot

# %%
import PIL
import numpy as np
import requests

# Prepare logo
bertopic_logo_response = requests.get(
    "https://raw.githubusercontent.com/MaartenGr/BERTopic/master/images/logo.png",
    stream=True,
    headers={'User-Agent': 'My User Agent 1.0'}
)
bertopic_logo = np.asarray(PIL.Image.open(bertopic_logo_response.raw))

# %% [markdown]
# We can use the labels created by the LLM and assign them to topics that we have created:

# %%
import datamapplot
import re

# Create a label for each document
llm_labels = [re.sub(r'\W+', ' ', label[0][0].split("\n")[0].replace('"', '')) for label in topic_model.get_topics(full=True)["LLM"].values()]
llm_labels = [label if label else "Unlabelled" for label in llm_labels]
all_labels = [llm_labels[topic+topic_model._outliers] if topic != -1 else "Unlabelled" for topic in topics]

# Run the visualization
datamapplot.create_plot(
    reduced_embeddings,
    all_labels,
    label_font_size=11,
    title="ArXiv - BERTopic",
    sub_title="Topics labeled with `openhermes-2.5-mistral-7b`",
    label_wrap_width=20,
    use_medoids=True,
    logo=bertopic_logo,
    logo_width=0.16
)
# Out:
# (<Figure size 1200x1200 with 1 Axes>,
#  <Axes: title={'left': 'Topics labeled with `openhermes-2.5-mistral-7b`'}>)
